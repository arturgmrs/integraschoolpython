# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffersonb7/integraschoolpython/blob/master/Trabalho_final_curso_python_grupo_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Trabalho Final para o Curso Python
# **Tema: O impacto da quarentena nos estudos dos alunos do curso Python e CentOs**
#
# Professor: Carlos Artur Guimarães
#
# Alunos: Gabrielly Fernandes, Hagliberto Alves de Oliveira, Jefferson Bruno Filgueira Soares, Paulo Aguiar Belarmino, Ormazabal Lima do Nascimento
#
# Repositório Github: https://github.com/jeffersonb7/python_8

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import plotly.graph_objects as go

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# código à respeito do gráfico "Em qual rede de ensino você estuda?"

# Número Randômico para a aleatoriedade
np.random.seed(19680801)

plt.rcdefaults()
fig, ax = plt.subplots()

# Opções do ensino Público e Privado
ensino = ('Pública', 'Privada')
y_pos = np.arange(len(ensino))
quantidade_pessoas = [12,2] 
# error = np.random.rand(len(ensino))

ax.barh(y_pos, quantidade_pessoas,height=0.5, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(ensino)
ax.invert_yaxis()  
ax.set_xlabel('Alunos')
ax.set_title('Quantidade de alunos por Ensino Público e Privado')

plt.xticks([0.0, 2.5, 5.0, 7.5, 10.0, 12.5]) 

plt.show()

# %%
# código à respeito do gráfico "Qual tipo de Ensino?"

# Número Randômico para a aleatoriedade
np.random.seed(19680801)

plt.rcdefaults()
fig, ax = plt.subplots()

# Opções do tipo de Ensino
ensino = ('Ensino Fundamental', 'Ensino Médio', 'Ensino Técnico', 'Ensino Médio Integrado ao Técnico', 'Ensino Superior', 'Pós Graduação')
y_pos = np.arange(len(ensino))
quantidade_pessoas = [0, 3, 5, 1, 5, 0] 

ax.barh(y_pos, quantidade_pessoas,height=0.5, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(ensino)
ax.invert_yaxis()  
ax.set_xlabel('Quantidade de Alunos')
ax.set_title('Tipos de Ensino')

plt.xticks([0, 2, 4, 6, 8, 10]) 

plt.show()

# %%
# código à respeito do gráfico "Você tem acesso à Internet?"

# Número Randômico para a aleatoriedade
np.random.seed(19680801)

plt.rcdefaults()
fig, ax = plt.subplots()

# Opções do tipo de Ensino
ensino = ('Sim, diariamente', 'Sim, semanalmente', 'Quinzenalmente', 'Mensalmente')
y_pos = np.arange(len(ensino))
quantidade_pessoas = [13, 0, 0, 1] 

ax.barh(y_pos, quantidade_pessoas,height=0.5, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(ensino)
ax.invert_yaxis()  
ax.set_xlabel('Quantidade de Alunos')
ax.set_title('Acesso à Internet')

plt.xticks(np.arange(0,15,2)) #modifica o eixo x

plt.show()

# %%
# código à respeito do gráfico "Tipo de internet disponível nas residências dos alunos"

labels = ["Fixa por assinatura(fibra cabo ou rádio própria ou compartilhada) ",
          "Sempre disponível no meu smartphone(3G/4G conta)",
          "Disponível no smartphone de outros quando tem crédito(3G/4G de terceiros)",
          "Disponível no meu smartphone quando tenho crédito(3G/4G crédito)",
          "Não possui acesso à internet",
          "Outros"]
values = [12, 1, 1, 0, 0, 0]

fig = go.Figure(data=[go.Pie(labels=labels, values=values, textfont_size=12 )])

fig.update_layout(title_text="TIPO DE INTERNET DISPONÍVEL NAS RESIDÊNCIAS DOS ALUNOS", font_size=12)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ed522d02-1d07-4521-8f3b-aee54f13c7c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ed522d02-1d07-4521-8f3b-aee54f13c7c9")) {
#                     Plotly.newPlot(
#                         'ed522d02-1d07-4521-8f3b-aee54f13c7c9',
# ...

# %%
# código à respeito do gráfico "Recursos tecnológicos disponível aos alunos"

labels = ["Computador de mesa (desktop) - Uso pessoal",
          "Computador de mesa (desktop) - Uso compartilhado",
          "Computador portátil (notebook, netbook) - Uso pessoal",
          "Computador portátil (notebook, netbook) - Uso compartilhado",
          "Smartphone e/ou Tablet - Uso pessoal",
          "Smartphone e/ou Tablet - Uso compartilhado",
          "Nenhum",
          "Notebook e smartphone - uso pessoal"]
values = [2, 1, 5, 2, 3, 0, 0, 1]

fig = go.Figure(data=[go.Pie(labels=labels, values=values, textfont_size=12 )])

fig.update_layout(title_text="Recursos tecnológicos disponível aos alunos", font_size=12)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3701a26a-d230-4997-995f-47dd01ece918" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3701a26a-d230-4997-995f-47dd01ece918")) {
#                     Plotly.newPlot(
#                         '3701a26a-d230-4997-995f-47dd01ece918',
# ...

# %%
# código à respeito do gráfico "Meio pelo qual os alunos têm acesso à internet"

labels = ["Por internet (vídeo aula, pdf, entre outros)",
          "Material Didático",
          "Não estou conseguindo estudar"]
values = [13, 1, 0]
fig = go.Figure(data=[go.Pie(labels=labels, values=values, textfont_size=12 )])

fig.update_layout(
    title_text="Meio pelo qual os alunos têm acesso à internet", font_size=12)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="59749afb-c150-48d5-98e2-4e5b872716f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("59749afb-c150-48d5-98e2-4e5b872716f5")) {
#                     Plotly.newPlot(
#                         '59749afb-c150-48d5-98e2-4e5b872716f5',
# ...

# %%
# código à respeito do gráfico "Você tem conseguido estudar na quarentena?"

# Número Randômico para a aleatoriedade
np.random.seed(19680801)

plt.rcdefaults()
fig, ax = plt.subplots()

# Opções do tipo de Ensino
ensino = ('Sim', 'Não', 'Às vezes')
y_pos = np.arange(len(ensino))
quantidade_pessoas = [9, 1, 3] 

ax.barh(y_pos, quantidade_pessoas,height=0.5, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(ensino)
ax.invert_yaxis()  
ax.set_xlabel('Quantidade de Alunos')
ax.set_title('Êxito de Estudo na Quarentena')

plt.xticks([0, 2, 4, 6, 8, 10]) #modifica o eixo x

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5cb6e267aac9> in <module>()
#       2
#       3 # Número Randômico para a aleatoriedade
# ----> 4 np.random.seed(19680801)
#       5
#       6 plt.rcdefaults()
#
# NameError: name 'np' is not defined

# %%
# código à respeito do gráfico "Qual tipo de ambiente para estudo você tem em casa?"

# Número Randômico para a aleatoriedade
np.random.seed(19680801)

plt.rcdefaults()
fig, ax = plt.subplots()

# Opções do tipo de Ensino
ensino = ('Ambiente privativo, confortável e silencioso', 'Ambiente compartilhado e/ou não silencioso', 'Não possui ambiente específico para estudo')
y_pos = np.arange(len(ensino))
quantidade_pessoas = [7, 5, 1] 

ax.barh(y_pos, quantidade_pessoas,height=0.5, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(ensino)
ax.invert_yaxis()  
ax.set_xlabel('Quantidade de Alunos')
ax.set_title('Tipo de Ambiente de Estudos dos Alunos')

plt.xticks([0, 2, 4, 6, 8]) #modifica o eixo x

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-13e864fa7e65> in <module>()
#       2
#       3 # Número Randômico para a aleatoriedade
# ----> 4 np.random.seed(19680801)
#       5
#       6 plt.rcdefaults()
#
# NameError: name 'np' is not defined

# %%
# código à respeito do gráfico "Como você considera a qualidade dos seus estudos??"
data = {'Muito Ruim': 1, '2': 1, '3': 3, '4': 4, 'Muito bom': 5}
names = list(data.keys())
values = list(data.values())

fig, axs = plt.subplots()
axs.bar(names, values)
fig.suptitle('Qualidade dos Estudos')
# Out:
# Text(0.5, 0.98, 'Qualidade dos Estudos')

# %%
# código à respeito do gráfico "Tem algum comentário relacionado impacto da quarentena nos seus estudos?"

# Libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt
 
# Create a list of word
text=("Sem comentários. Tenho conseguido estudar e até tenho tido mais tempo, pois a pandemia tem trazido o isolamento social e com o isolamento mais tempo livre. Está atrapalhando os meus estudos para o ENEM A cada dia um impacto diferente na minha vida, afetando muito psicologicamente, tanto no financeiro, quanto em outros problemas que surgem... Nenhum - falta de dinheiro nao")
# Create the wordcloud object
wordcloud = WordCloud(width=480, height=480, margin=0).generate(text)
 
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
